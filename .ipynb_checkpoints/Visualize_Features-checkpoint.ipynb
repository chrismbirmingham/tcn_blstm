# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from score import collect_data, score
import os
from scipy import stats

# %%
def compare_distributions(sets, variable, categories=["A","B"], save=True):
    title=f"Comparing Distributions of {variable}"
    max_cat_size=22
    t, p = stats.ttest_ind(sets[0], sets[1])
    text=""
    if p/2 < .05:
        text = "\nDistributions PROBABLY SIGNIFICANTLY Different"
        title = "*"+title+"*"  
    
    text = text+f"\nt-value = {t:.04f} \np-value = {p/2:.04f}"

    categories = [c[:max_cat_size] for c in categories]
    
    for i in range(len(categories)):
        text = text + f"\nMean of {categories[i]}: {np.mean(sets[i]):.04f}"
        text = text + f"\nStandard Deviation of  {categories[i]}: {np.std(sets[i]):.04f}"
    text = text + f"\nEffect Size: {(np.mean(sets[1])-np.mean(sets[0]))/np.std(sets[0]):.04f}"
        
        
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 6))

    axes[0].violinplot(sets,
                    showmeans=False,
                    showmedians=True)
    axes[0].set_title(title)

    # plot box plot
    axes[1].boxplot(sets)
    axes[1].set_title(title)

    #n, bins, patches = ax.hist(, num_bins, density=1)
    axes[2].hist(sets, 20, density=False, histtype='bar', stacked=False, label=categories)
    axes[2].set_title(title)
    axes[2].legend(prop={'size': 10})
    axes[2].set_ylabel("samples")
    axes[2].set_xlabel(variable)

    # adding horizontal grid lines
    for ax in axes:
        ax.yaxis.grid(True)
        if ax != axes[2]:
            ax.set_xticks([y + 1 for y in range(len(sets))])
            ax.set_xlabel("")
            ax.set_ylabel(variable)
    axes[1].set_xlabel(text)
    # add x-tick labels
    plt.setp(axes[:2], xticks=[y + 1 for y in range(len(sets))],xticklabels=categories)
    plt.show()

# %%
df_list = []
folders = os.listdir("data")
for folder in folders:
    print(folder)
    if not os.path.isdir(os.path.join("data", folder)):
        continue
    df_list.append(pd.read_feather(f"data/{folder}/analysis_df_.feather"))

# full_df = pd.read_feather("data/1l/analysis_df_.feather")
full_df = pd.concat(df_list)
print(full_df.shape)

pose = ["pose_Rx", "pose_Ry"]
original_conf = ["sConf","pConf"]
speech_conf = [c for c in full_df.columns if "-SPEECH" in c]
turn_conf = [c for c in full_df.columns if "-TURN" in c]
ang = ["p1_ang","p2_ang"]
at = ["p1_at","p2_at"]


# display(full_df)
# Out:
# 13l
# 3c
# 8c
# 10r
# 20c
# 6r
# 22c
# 24l
# 25c
# 3r
# 23c
# 8r
# 22r
# 2l
# 12c
# 15l
# 9c
# 13r
# 16l
# 11l
# 20r
# 8l
# 7l
# 24r
# 27r
# 27c
# 16r
# 15r
# 22l
# 7r
# 24c
# 9r
# 6c
# 15c
# 10c
# 2r
# 20l
# 11r
# 25l
# 9l
# 23r
# 1r
# 23l
# 13c
# 1c
# 12l
# 2c
# 12r
# 1l
# 3l
# 10l
# 7c
# 6l
# 11c
# 25r
# 16c
# (1474144, 26)

# %% [markdown]
# # Comparing Headpose When Models are Correct vs Incorrect
#
# Here we can see that when the models are wrong the headpose tends to be different from when the models are right

# %%
columns = pose

cond1A = full_df["TCN-SYNCNET-SPEECH-1Conf"] < full_df["TCN-SYNCNET-SPEECH-0Conf"] #TCN thinks speaking
cond2A = full_df["SPEECH-LABEL"] == 1
dfA = full_df[columns][cond1A & cond2A]

cond1B = full_df["TCN-SYNCNET-SPEECH-1Conf"] > full_df["TCN-SYNCNET-SPEECH-0Conf"] #TCN thinks not speaking
cond2B = full_df["SPEECH-LABEL"] == 1

dfB = full_df[columns][cond1B & cond2B]

data_to_compare = [dfA,dfB]
for c in columns:
    sets = [df[c].values for df in data_to_compare]
    compare_distributions(sets, c, categories=["Correct","Incorrect"], save=False)
# plot_hist(data_to_compare, columns, "TCN Speech Correct vs Incorrect")

# %%
columns = pose

cond1A = full_df["sConf"] > 0 #Sync thinks speaking
cond2A = full_df["SPEECH-LABEL"] == 1
dfA = full_df[columns][cond1A & cond2A]

cond1B = full_df["sConf"] < 0 #Sync thinks not speaking
cond2B = full_df["SPEECH-LABEL"] == 1

dfB = full_df[columns][cond1B & cond2B]
print("Comparing head rotation and syncnet performance while talking")
data_to_compare = [dfA,dfB]
for c in columns:
    sets = [df[c].values for df in data_to_compare]
    compare_distributions(sets, c, categories=["Correct","Incorrect"], save=False)
    
cond1A = full_df["sConf"] < 0 #Sync thinks not speaking
cond2A = full_df["SPEECH-LABEL"] == 0
dfA = full_df[columns][cond1A & cond2A]

cond1B = full_df["sConf"] > 0 #Sync thinks speaking
cond2B = full_df["SPEECH-LABEL"] == 0

dfB = full_df[columns][cond1B & cond2B]
print("Comparing head rotation and syncnet performance while NOT talking")

data_to_compare = [dfA,dfB]
for c in columns:
    sets = [df[c].values for df in data_to_compare]
    compare_distributions(sets, c, categories=["Correct","Incorrect"], save=False)
# Out:
# Comparing head rotation and syncnet performance while talking
# Comparing head rotation and syncnet performance while NOT talking

# %%
columns = pose

cond1A = full_df["pConf"] > 0 #Sync thinks speaking
cond2A = full_df["SPEECH-LABEL"] == 1
dfA = full_df[columns][cond1A & cond2A]

cond1B = full_df["pConf"] < 0 #Sync thinks not speaking
cond2B = full_df["SPEECH-LABEL"] == 1

dfB = full_df[columns][cond1B & cond2B]
print("Comparing head rotation and syncnet performance while talking")
data_to_compare = [dfA,dfB]
for c in columns:
    sets = [df[c].values for df in data_to_compare]
    compare_distributions(sets, c, categories=["Correct","Incorrect"], save=False)
    
cond1A = full_df["pConf"] < 0 #Sync thinks not speaking
cond2A = full_df["SPEECH-LABEL"] == 0
dfA = full_df[columns][cond1A & cond2A]

cond1B = full_df["pConf"] > 0 #Sync thinks speaking
cond2B = full_df["SPEECH-LABEL"] == 0

dfB = full_df[columns][cond1B & cond2B]
print("Comparing head rotation and syncnet performance while NOT talking")

data_to_compare = [dfA,dfB]
for c in columns:
    sets = [df[c].values for df in data_to_compare]
    compare_distributions(sets, c, categories=["Correct","Incorrect"], save=False)
# Out:
# Comparing head rotation and syncnet performance while talking
# Comparing head rotation and syncnet performance while NOT talking

# %% [markdown]
# # Calculating model performance for different head rotations

# %%
def score_df(df, label="SPEECH"):
    #acc, f1, auroc, mAP = score(targets, outputs)
    scores = {}
    # Score original models
    for m in ["sConf","pConf"]:
        outputs1 = df[m].values
        outputs0 = -1* df[m].values
        outputs = np.array(list(zip(outputs0,outputs1)), dtype=object)

        acc, f1, auroc, mAP = score(df[f"{label}-LABEL"].values, outputs)
        scores[m] = {"acc":acc,"f1":f1,"auROC":auroc,"mAP":mAP}
        
    # Score newly trained models
    for m in ["TCN","BLSTM"]:#"TCN",
        for f in ["SYNCNET","PERFECTMATCH"]:
            outputs1 = df[f"{m}-{f}-{label}-1Conf"].values
            outputs0 = df[f"{m}-{f}-{label}-0Conf"].values
            outputs = np.array(list(zip(outputs0,outputs1)), dtype=object)
            
            acc, f1, auroc, mAP = score(df[f"{label}-LABEL"].values, outputs)
            scores[f"{m}-{f}"] = {"acc":acc,"f1":f1,"auROC":auroc,"mAP":mAP}
            
    return scores

s = score_df(full_df, label="TURN")
for k,v in s.items():
    print(k,v)    

# cond1A = full_df["pConf"] > 0 #Sync thinks speaking
# cond2A = full_df["SPEECH-LABEL"] == 1
# dfA = full_df[columns][cond1A & cond2A]
# Out:
# sConf {'acc': 0.6227091790218595, 'f1': 0.5523841869201902, 'auROC': 0.6996413009691703, 'mAP': 0.6185452731422225}
# pConf {'acc': 0.7190396596261966, 'f1': 0.6312995175102819, 'auROC': 0.896512317332769, 'mAP': 0.8565090343433481}
# TCN-SYNCNET {'acc': 0.9495951548831051, 'f1': 0.9042091557194241, 'auROC': 0.9839100487853628, 'mAP': 0.9767323906572414}
# TCN-PERFECTMATCH {'acc': 0.938293002583194, 'f1': 0.8829557955956433, 'auROC': 0.9758244628712458, 'mAP': 0.9657652710471121}
# BLSTM-SYNCNET {'acc': 0.9351304892873423, 'f1': 0.8761293849280626, 'auROC': 0.9724712360931238, 'mAP': 0.9624438908687105}
# BLSTM-PERFECTMATCH {'acc': 0.9414711181539931, 'f1': 0.8850056910720806, 'auROC': 0.9784857764081206, 'mAP': 0.9700978197424392}

# %%
# full_df["pose_Rx"].plot.hist()
# full_df["pose_Ry"].plot.hist()
num_windows=5

for r in ["pose_Rx", "pose_Ry"]:
    print(r, "range", min(full_df[r]),max(full_df[r]))
    window = (max(full_df[r]) - min(full_df[r]))/num_windows
    
    for i in range(num_windows):
        rmin = min(full_df[r]) + window * i
        rmax = min(full_df[r]) + window * (i+1)
        sub_df = full_df[(full_df[r]>=rmin) & (full_df[r]<rmax)]
        
        print(f"Range is {rmin:.3f}, {rmax:.3f} and support is {len(sub_df)}")
        s = score_df(sub_df, label="TURN")
        
        print("\t\t\t\t\t\t",[f"{k}: {v:.3f}" for k,v, in s["sConf"].items()])
# Out:
# pose_Rx range -3.133 3.136
# Range is -3.133, -1.879 and support is 94
# 						 ['acc: 0.723', 'f1: 0.071', 'auROC: 0.828', 'mAP: 0.528']
# Range is -1.879, -0.625 and support is 84334
# 						 ['acc: 0.633', 'f1: 0.592', 'auROC: 0.701', 'mAP: 0.632']
# Range is -0.625, 0.628 and support is 1389402
# 						 ['acc: 0.622', 'f1: 0.550', 'auROC: 0.700', 'mAP: 0.618']
# Range is 0.628, 1.882 and support is 209
# 						 ['acc: 0.737', 'f1: 0.641', 'auROC: 0.755', 'mAP: 0.649']
# Range is 1.882, 3.136 and support is 104
# 						 ['acc: 0.913', 'f1: 0.400', 'auROC: 0.960', 'mAP: 0.660']
# pose_Ry range -1.509 1.569
# Range is -1.509, -0.893 and support is 1547
# 						 ['acc: 0.519', 'f1: 0.244', 'auROC: 0.598', 'mAP: 0.525']
# Range is -0.893, -0.278 and support is 132385
# 						 ['acc: 0.622', 'f1: 0.581', 'auROC: 0.684', 'mAP: 0.621']
# Range is -0.278, 0.338 and support is 1233026
# 						 ['acc: 0.623', 'f1: 0.551', 'auROC: 0.700', 'mAP: 0.618']
# Range is 0.338, 0.953 and support is 106673
# 						 ['acc: 0.624', 'f1: 0.540', 'auROC: 0.719', 'mAP: 0.629']
# Range is 0.953, 1.569 and support is 512
# 						 ['acc: 0.527', 'f1: 0.148', 'auROC: 0.626', 'mAP: 0.519']

# %%
def scatter_hist(x, y, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y)

    # now determine nice limits by hand:
    binwidth = 0.1
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=bins)
    ax_histy.hist(y, bins=bins, orientation='horizontal')

def double_scatter(x,y):    
    fig, ax = plt.subplots(tight_layout=True)
    hist = ax.hist2d(x, y, bins=100)
    plt.show()
    # definitions for the axes
    left, width = 0.1, 0.65
    bottom, height = 0.1, 0.65
    spacing = 0.005


    rect_scatter = [left, bottom, width, height]
    rect_histx = [left, bottom + height + spacing, width, 0.2]
    rect_histy = [left + width + spacing, bottom, 0.2, height]

    # start with a square Figure
    fig = plt.figure(figsize=(8, 8))

    ax = fig.add_axes(rect_scatter)
    ax_histx = fig.add_axes(rect_histx, sharex=ax)
    ax_histy = fig.add_axes(rect_histy, sharey=ax)

    # use the previously defined function
    scatter_hist(x, y, ax, ax_histx, ax_histy)

    plt.show()

    fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
    n_bins=20
    # We can set the number of bins with the `bins` kwarg
    axs[0].hist(x, bins=n_bins)
    axs[1].hist(y, bins=n_bins)
    plt.show()
    
d=(all_confidences[:,1]>=0.15) & (all_confidences[:,1]<=0.85)
x = all_confidences[d,1]
y=avg_ang[d]
double_scatter(x,y)

# %%
data_path="data"
model_type="BLSTM"
feature_type="SYNCNET"
label_type="SPEECH"
model_trainer="kalin"

all_confidences, all_labels, all_gazes = collect_data(data_path, model_type, feature_type, label_type, model_trainer)
# acc, f1, auroc, mAP
print(score(all_labels, all_confidences))
all_confidences = math.e**all_confidences
print(score(all_labels, all_confidences))

avg_ang = (all_gazes[:,0] +all_gazes[:,1])/2
avg_at = (all_gazes[:,2] +all_gazes[:,3])/2

print(score(all_labels, all_confidences))
# Out:
# (0.48127666996986673, 0.4472838200930646, 0.6621731694807959, 0.6373531377376087)
# (0.48127666996986673, 0.4472838200930646, 0.6621731694807959, 0.6373531377376087)
# 1582304
# array([[0.17954062, 0.3291074 , 1.        , 0.        ],
#        [0.17677538, 0.33964667, 1.        , 0.        ],
#        [0.20620258, 0.33852765, 1.        , 0.        ],
#        ...,
#        [1.05048044, 1.65786819, 0.        , 0.        ],
#        [1.0493472 , 1.65801373, 0.        , 0.        ],
#        [1.04599312, 1.65838739, 0.        , 0.        ]])

# %%
d=all_labels==0
all_data = [all_confidences[d,0],all_confidences[d,1]]
plot_hist(all_data,"Not Speaking")
d=all_labels==1
all_data = [all_confidences[d,0],all_confidences[d,1]]
plot_hist(all_data,"Speaking")

# %%
lower_bound=1
upper_bound=2

m = (lower_bound-upper_bound)/75
gazes_mult = avg_ang  * (180/math.pi) * m + upper_bound


d=all_labels==0
all_data = [gazes_mult[d],gazes_mult[d]]
plot_hist(all_data,"Not Speaking")
d=all_labels==1
all_data = [gazes_mult[d],gazes_mult[d]]
plot_hist(all_data, "Speaking")
